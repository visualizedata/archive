# %%
from fork_repos import fork_all

TOKEN = "EXAMPLE_github_pat_1234_ABCDEF"

THESIS_REPOS_2026 = {
  "narmanios/louis-armstrong": "neven-armanios",
  "oliviakasmin/okasmin-parsons-thesis-2026": "olivia-kasmin",
  "hoonkim0123/thesis": "saehun-kim",
  "smolinaschmidt/Thesis": "sofia-molina",
  "nmolnar-parsons/thesis": "nichos-molnar",
  "mnav0/thesis": "maggie-navracruz",
  "pabspadres/thesis": "luispablo-padres",
  "derinsavasan/thesis": "derin-savasan",
  "lara-yeyati-preiss/space-talk": "lara-yeyati-preiss",
}

# %%
def fork_name(url):
  return f"{THESIS_REPOS_2026[url]}-thesis-2026"
  
succ, fail = fork_all(THESIS_REPOS_2026.keys(), "visualizedata", TOKEN, fork_name)

display("SUCCESS!", succ)
display("FAILED", fail)
